# %% [markdown]
# # Hipotese H2 - periodos intensos e sinistros fatais
#
# H2 avalia se fins de semana, feriados nacionais e meses de ferias (janeiro, julho e dezembro) concentram maior frequencia de sinistros e maior proporcao de ocorrencias fatais.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'labs' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

from prf_sdk.analysis.hypotheses.h2 import run_h2_analysis

result = run_h2_analysis()
result['status'], result['evidence'], result['support_metric']
# Out:
# ('Validada',
#  'Periodos intensos registram 201.2 sinistros/dia contra 178.8 nos demais dias, com proporcao fatal de 7.74% contra 6.56%.',
#  'Teste z de duas proporcoes: z=12.59, p=2.34e-36, RR=1.181.')

# %%
summary = result['summary'].copy()
summary['proporcao_fatal_pct'] = summary['proporcao_fatal'] * 100

if 'sinistros_fatais_por_dia' not in summary.columns:
    summary['sinistros_fatais_por_dia'] = (
        summary['sinistros_fatais'] / summary['dias_observados']
    )

summary[['recorte', 'grupo', 'dias_observados', 'sinistros', 'sinistros_por_dia', 'sinistros_fatais', 'sinistros_fatais_por_dia', 'proporcao_fatal_pct', 'mortos']]
# Out:
#                       recorte                                     grupo  \
# 0               Fim de semana                             Fim de semana
# 1               Fim de semana               Demais dias - Fim de semana
# 2            Feriado nacional                          Feriado nacional
# 3            Feriado nacional            Demais dias - Feriado nacional
# 4        Ferias (jan/jul/dez)                      Ferias (jan/jul/dez)
# 5        Ferias (jan/jul/dez)        Demais dias - Ferias (jan/jul/dez)
# 6  Periodo intenso (qualquer)                Periodo intenso (qualquer)
# 7  Periodo intenso (qualquer)  Demais dias - Periodo intenso (qualquer)
#
#    dias_observados  sinistros  sinistros_por_dia  sinistros_fatais  \
# 0              452      97558         215.836283              8114
# 1             1129     202528         179.387068             13415
# 2               55      10341         188.018182               811
# 3             1526     289745         189.872215             20718
# 4              403      77166         191.478908              5569
# 5             1178     222920         189.235993             15960
# 6              776     156123         201.189433             12090
# 7              805     143963         178.836025              9439
#
#    sinistros_fatais_por_dia  proporcao_fatal_pct  mortos
# 0                 17.951327             8.317104    9586
# 1                 11.882197             6.623775   15550
# 2                 14.745455             7.842568     947
# 3                 13.576671             7.150425   24189
# 4                 13.818859             7.216909    6654
# 5                 13.548387             7.159519   18482
# 6                 15.579897             7.743894   14273
# 7                 11.725466             6.556546   10863

# %%
tests = result['tests'].copy()
tests[['group', 'group_n', 'reference_n', 'group_rate', 'reference_rate', 'difference', 'relative_risk', 'z_statistic', 'p_value']]
# Out:
#                                                group  group_n  reference_n  \
# 0                                      Fim de semana    97558       202528
# 1                                   Feriado nacional    10341       289745
# 2                               Ferias (jan/jul/dez)    77166       222920
# 3  Periodo intenso (fim de semana, feriado ou fer...   156123       143963
#
#    group_rate  reference_rate  difference  relative_risk  z_statistic  \
# 0    0.083171        0.066238    0.016933       1.255644    16.837167
# 1    0.078426        0.071504    0.006921       1.096797     2.680026
# 2    0.072169        0.071595    0.000574       1.008016     0.532448
# 3    0.077439        0.065565    0.011873       1.181094    12.591892
#
#         p_value
# 0  1.303283e-63
# 1  7.361645e-03
# 2  5.944161e-01
# 3  2.339974e-36

# %% [markdown]
# ## Interpretacao
#
# A hipotese foi validada para o indicador composto de periodo intenso: fins de semana, feriados ou meses de ferias apresentam maior frequencia diaria de sinistros e maior proporcao de sinistros fatais em relacao aos demais dias. A dimensao de ferias isolada tem aumento pequeno e sem significancia estatistica na proporcao fatal, portanto o efeito agregado e puxado principalmente por fins de semana e feriados.
